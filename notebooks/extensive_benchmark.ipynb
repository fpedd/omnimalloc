# %%
# %load_ext autoreload
# %autoreload 2

# %%
from omnimalloc.benchmark import (
    run_benchmark,
    plot_benchmark,
    save_benchmark,
)

# %%
allocators = (
    "greedy_by_size_allocator",
    "greedy_by_size_allocator_cpp",
    "greedy_by_area_allocator",
    "greedy_by_conflict_allocator",
    # "minimalloc_allocator",
)

sources = (
    "random_source",
    "minimalloc_source",
    # "huggingface_source",
)

variants = (10, 100, 500, 1_000, 2_000, 5_000, 10_000)

# %%
campaign = run_benchmark(
    allocators=allocators,
    sources=sources,
    variants=variants,
    validate=True,
)
plot_benchmark(campaign)
# save_benchmark(campaign, "benchmark_results")
